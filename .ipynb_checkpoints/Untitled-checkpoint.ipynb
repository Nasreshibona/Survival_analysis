# %%
import pandas as pd

# %%
df = pd.read_csv("expr_degs.csv")

# %%
df
# Out:
#               sample  1554679_a_at  201540_at  202565_s_at  202887_s_at  \
# 0   GSM158713.CEL.gz     10.601766   9.271564     9.972121    10.144884
# 1   GSM158724.CEL.gz     11.172171  10.188306     9.564933     9.344057
# 2   GSM158726.CEL.gz      8.065759   9.926397     8.081620    10.497431
# 3   GSM158739.CEL.gz      7.840191   9.377725     9.464197     9.594888
# 4   GSM158762.CEL.gz      7.925099   9.695357     8.788698    10.712332
# ..               ...           ...        ...          ...          ...
# 92  GSM159034.CEL.gz      9.025284   7.990120     8.490336     8.829432
# 93  GSM159035.CEL.gz      7.723572   8.326087     7.912357     9.703860
# 94  GSM159078.CEL.gz      7.389946   9.205484     9.257929    10.963252
# 95  GSM159090.CEL.gz      8.110723   7.923169     6.517957     8.775466
# 96  GSM159094.CEL.gz      7.447646  10.277935     7.240839     9.995132
#
#     203373_at  203753_at  205609_at  206310_at  206478_at  ...  212382_at  \
# ...

# %%
data = pd.read_csv("data_osi.csv", sep = ",")
data
# Out:
#                ID_REF  sample  sample.1   ID_REF.1  cohort    osi    os  \
# 0    GSM158764.CEL.gz    1197      1197  GSM158764       1  alive  3561
# 1    GSM158765.CEL.gz    1299      1299  GSM158765       1  alive  2533
# 2    GSM158766.CEL.gz    1316      1316  GSM158766       1  alive  3243
# 3    GSM158776.CEL.gz    2173      2173  GSM158776       1  alive  6327
# 4    GSM158777.CEL.gz    2174      2174  GSM158777       1  alive  6426
# ..                ...     ...       ...        ...     ...    ...   ...
# 443  GSM159155.CEL.gz    7419      7419  GSM159155       2   dead   406
# 444  GSM159156.CEL.gz    7420      7420  GSM159156       2   dead   652
# 445  GSM159157.CEL.gz    7421      7421  GSM159157       2   dead   256
# 446  GSM159158.CEL.gz    7423      7423  GSM159158       2   dead    60
# 447  GSM159159.CEL.gz    7479      7479  GSM159159       2   dead    42
#
#        efsi     efs     title geo_accession characteristics_ch1.4       age  \
# ...

# %%
df2 = pd.merge(df , data , how = "inner", on = "sample")
